# %%
# Out:
#    Wafer  Layer thickness
# 0      1               11
# 1      2               16
# 2      3               22
# 3      4               14
# 4      5               34

# %% [markdown]
# # Q1

# %%
#Normality looks like it can benfit from log transformation

# %% [markdown]
# # Q2

# %%
#Log does improve the normality so we will stick with it

# %% [markdown]
# MR Chart
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
# Out:
# The centeral limit for the MR chart is 0.3508855205640929
# The upper limit for the MR chart is 1.1463429956828914
# The lowe limit for the MR chart is 0
# Estimated Process Sigma is 0.3110687239043377

# %%
# Out:
# The centeral limit for the X chart is 2.653095195248599
# The upper limit for the X chart is 3.586301366961612
# The lowe limit for the X chart is 1.719889023535586

# %%
# The process is in control

# %% [markdown]
# # Q3
# The centeral limit for the MR chart is 0.3508855205640929
# The upper limit for the MR chart is 1.1463429956828914
# The lowe limit for the MR chart is 0

# %% [markdown]
# # Q4
#
# Estimated Process Sigma is 0.3110687239043377

# %% [markdown]
# # Q5
#
# The centeral limit for the X chart is 2.653095195248599
# The upper limit for the X chart is 3.586301366961612
# The lowe limit for the X chart is 1.719889023535586

# %% [markdown]
# # Q6
#
# The mean estimate (i.e. centeral limit for the X chart) is 2.653095195248599

# %% [markdown]
# # Q7 to Q9
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
#Q7 Power is equal to 0.9902527632595419
#Q8 ARL= 1.0098431805515733 runs
#Q9 The probability of detecting this transformation on the 4th sample is 9.170449125911425e-07
